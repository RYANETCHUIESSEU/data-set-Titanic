# %%
import pandas as pd  # Assurez-vous que 'pandas' est bien installé

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
print(df.info())  # Aperçu des colonnes et des types de données
print(df.describe())  # Statistiques descriptives
print(df.isnull().sum())  # Vérifier les valeurs manquantes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                        --------------  -----
#  0   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"  41188 non-null  object
# dtypes: object(1)
# memory usage: 321.9+ KB
# None
#        age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# count                                               41188
# unique                                              41176
# top     36;"retired";"married";"unknown";"no";"no";"no...
# freq                                                    2
# age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"    0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"'], dtype='object')

# %%
df.columns = df.columns.str.strip()  # Supprime les espaces inutiles
df.columns = df.columns.str.lower()  # Convertit les noms en minuscules pour uniformiser
print(df.columns)  # Vérifiez à nouveau les colonnes
# Out:
# Index(['age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"'], dtype='object')

# %%
print(df.head())  # Affiche les 5 premières lignes du DataFrame
# Out:
#   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0  56;"housemaid";"married";"basic.4y";"no";"no";...
# 1  57;"services";"married";"high.school";"unknown...
# 2  37;"services";"married";"high.school";"no";"ye...
# 3  40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4  56;"services";"married";"high.school";"no";"no...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = df.drop(['alive','who','embarked','class','deck'], axis = 1)
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500        True
# 1         1       1  female  38.0      1      0  71.2833       False
# 2         1       3  female  26.0      0      0   7.9250       False
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   adult_male   891 non-null    bool
#  8   embark_town  889 non-null    object
#  9   alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(2)
# memory usage: 57.6+ KB

# %%
sns.countplot(x = 'survived', data=df);

# %%
df['survived'].value_counts(normalize = True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
sns.countplot(x = 'pclass', data=df);

# %%
sns.countplot(x = 'sex' , data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(y = 'age', data = df)
# Out:
# <Axes: ylabel='age'>

# %%
sns.distplot(df['age'], kde=False, bins=20);
# Out:
# C:\Users\ryane\AppData\Local\Temp\ipykernel_22700\1173224801.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'], kde=False, bins=20);

# %%
sns.countplot(x = 'sibsp' , data=df)
# Out:
# <Axes: xlabel='sibsp', ylabel='count'>

# %%
sns.boxplot(y= 'fare',data = df)
# Out:
# <Axes: ylabel='fare'>

# %%
sns.displot(df['fare'], kde=False);

# %%
sns.countplot(x = 'adult_male' , data=df)
# Out:
# <Axes: xlabel='adult_male', ylabel='count'>

# %%
pd.crosstab(df['sex'],df['adult_male'])
# Out:
# adult_male  False  True
# sex
# female        314      0
# male           40    537

# %%
sns.countplot(x = 'embark_town', data=df);

# %%
sns.boxplot(x = 'survived',y = 'age', data=df);

# %%
sns.boxplot(x = 'survived' ,y = 'age' , hue = 'sex',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x='survived',y = 'fare', data = df);

# %%
sns.boxplot(x='survived',y = 'fare',hue= 'pclass' ,data = df);

# %%
sns.boxplot(x='survived',y = 'fare',hue= 'sex' ,data = df);

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['fare'].quantile(0.99)
# Out:
# np.float64(249.00622000000035)

# %% [markdown]
# valeur manquantes

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# adult_male       0
# embark_town      2
# alone            0
# dtype: int64

# %%
df.shape
# Out:
# (891, 10)

# %%
df.fillna(value={'age':df['age'].mean()},inplace=True)

# %%
df['age'].std()
# Out:
# np.float64(13.002015226002882)

# %%
df['embark_town'].value_counts(normalize=True)
# Out:
# embark_town
# Southampton    0.724409
# Cherbourg      0.188976
# Queenstown     0.086614
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"    0
# dtype: int64

# %%
df.fillna(value={'age':'Southampton'}, inplace=True)

# %%
df.isna().sum()
# Out:
# age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"    0
# dtype: int64

# %%
def finding_outliers(data,variable_name):
    iqr = data[variable_name].quantile(0.75) - data[variable_name].quantile(0.25)
    lower = data[variable_name].quantile(0.25) - 1.5 * iqr
    upper = data[variable_name].quantile(0.75) + 1.5 * iqr
    return data[(data[variable_name] < lower) | (data[variable_name] > upper)]

# %%
finding_outliers(df, 'fare').sort_values('fare')
# Out:
#      survived  pclass     sex        age  sibsp  parch      fare  adult_male  \
# 151         1       1  female  22.000000      1      0   66.6000       False
# 336         0       1    male  29.000000      1      0   66.6000        True
# 369         1       1  female  24.000000      0      0   69.3000       False
# 641         1       1  female  24.000000      0      0   69.3000       False
# 201         0       3    male  29.699118      8      2   69.5500        True
# ..        ...     ...     ...        ...    ...    ...       ...         ...
# 341         1       1  female  24.000000      3      2  263.0000       False
# 438         0       1    male  64.000000      1      4  263.0000        True
# 258         1       1  female  35.000000      0      0  512.3292       False
# 679         1       1    male  36.000000      0      1  512.3292        True
# 737         1       1    male  35.000000      0      0  512.3292        True
#
#      embark_town  alone
# 151  Southampton  False
# 336  Southampton  False
# 369    Cherbourg   True
# 641    Cherbourg   True
# 201  Southampton  False
# ..           ...    ...
# 341  Southampton  False
# 438  Southampton  False
# 258    Cherbourg   True
# 679    Cherbourg  False
# 737    Cherbourg   True
#
# [116 rows x 10 columns]

# %%
iqr_fare = df['fare'].quantile(0.75) - df['fare'].quantile(0.25)
df['fare'].quantile(0.75) + 1.5* iqr_fare
# Out:
# np.float64(65.6344)

# %%
df['fare'].quantile(0.75) + 1.5 * (df['fare'].quantile(0.75) + 1.5 * iqr_fare)
# Out:
# np.float64(129.41875)

# %%
df.loc[(finding_outliers(df,'fare').index, 'fare')] = df ['fare'].quantile(0.75) + 1.5 * iqr_fare

# %%
sns.boxplot(y = 'fare', data=df);

# %%
df['age'].quantile(0.25)- 1.5 * (df['age'].quantile(0.75) - df['age'].quantile(0.25))
# Out:
# np.float64(2.5)

# %%
df['age'].quantile(0.75) + 1.5 * (df['age'].quantile(0.75) - df['age'].quantile(0.25))
# Out:
# np.float64(54.5)

# %%
finding_outliers(df,'age').sort_values('age')
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare  adult_male  \
# 803         1       3    male   0.42      0      1   8.5167       False
# 755         1       2    male   0.67      1      1  14.5000       False
# 644         1       3  female   0.75      2      1  19.2583       False
# 469         1       3  female   0.75      2      1  19.2583       False
# 78          1       2    male   0.83      0      2  29.0000       False
# ..        ...     ...     ...    ...    ...    ...      ...         ...
# 116         0       3    male  70.50      0      0   7.7500        True
# 493         0       1    male  71.00      0      0  49.5042        True
# 96          0       1    male  71.00      0      0  34.6542        True
# 851         0       3    male  74.00      0      0   7.7750        True
# 630         1       1    male  80.00      0      0  30.0000        True
#
#      embark_town  alone
# 803    Cherbourg  False
# 755  Southampton  False
# 644    Cherbourg  False
# 469    Cherbourg  False
# 78   Southampton  False
# ..           ...    ...
# 116   Queenstown   True
# 493    Cherbourg   True
# 96     Cherbourg   True
# 851  Southampton   True
# 630  Southampton   True
#
# [66 rows x 10 columns]

# %%
df.loc[df['age'] < df['age'].quantile(0.25)- 1.5 * (df['age'].quantile(0.75) - df['age'].quantile(0.25))]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  adult_male  \
# 7           0       3    male  2.00      3      1  21.0750       False
# 16          0       3    male  2.00      4      1  29.1250       False
# 78          1       2    male  0.83      0      2  29.0000       False
# 119         0       3  female  2.00      4      2  31.2750       False
# 164         0       3    male  1.00      4      1  39.6875       False
# 172         1       3  female  1.00      1      1  11.1333       False
# 183         1       2    male  1.00      2      1  39.0000       False
# 205         0       3  female  2.00      0      1  10.4625       False
# 297         0       1  female  2.00      1      2  65.6344       False
# 305         1       1    male  0.92      1      2  65.6344       False
# 340         1       2    male  2.00      1      1  26.0000       False
# 381         1       3  female  1.00      0      2  15.7417       False
# 386         0       3    male  1.00      5      2  46.9000       False
# 469         1       3  female  0.75      2      1  19.2583       False
# 479         1       3  female  2.00      0      1  12.2875       False
# 530         1       2  female  2.00      1      1  26.0000       False
# 642         0       3  female  2.00      3      2  27.9000       False
# 644         1       3  female  0.75      2      1  19.2583       False
# 755         1       2    male  0.67      1      1  14.5000       False
# 788         1       3    male  1.00      1      2  20.5750       False
# 803         1       3    male  0.42      0      1   8.5167       False
# 824         0       3    male  2.00      4      1  39.6875       False
# 827         1       2    male  1.00      0      2  37.0042       False
# 831         1       2    male  0.83      1      1  18.7500       False
#
#      embark_town  alone
# 7    Southampton  False
# 16    Queenstown  False
# 78   Southampton  False
# 119  Southampton  False
# 164  Southampton  False
# 172  Southampton  False
# 183  Southampton  False
# 205  Southampton  False
# 297  Southampton  False
# 305  Southampton  False
# 340  Southampton  False
# 381    Cherbourg  False
# 386  Southampton  False
# 469    Cherbourg  False
# 479  Southampton  False
# 530  Southampton  False
# 642  Southampton  False
# 644    Cherbourg  False
# 755  Southampton  False
# 788  Southampton  False
# 803    Cherbourg  False
# 824  Southampton  False
# 827    Cherbourg  False
# 831  Southampton  False

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
embark_dummies = pd.get_dummies(df['embark_town'],drop_first=True)
embark_dummies
# Out:
#      Queenstown  Southampton
# 0         False         True
# 1         False        False
# 2         False         True
# 3         False         True
# 4         False         True
# ..          ...          ...
# 886       False         True
# 887       False         True
# 888       False         True
# 889       False        False
# 890        True        False
#
# [891 rows x 2 columns]

# %%
df = pd.concat([df,embark_dummies], axis=1)
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500        True
# 1         1       1  female  38.0      1      0  65.6344       False
# 2         1       3  female  26.0      0      0   7.9250       False
#
#    embark_town  alone  Queenstown  Southampton
# 0  Southampton  False       False         True
# 1    Cherbourg  False       False        False
# 2  Southampton   True       False         True

# %%
del df['embark_town']
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  adult_male  alone  \
# 0         0       3    male  22.0      1      0   7.2500        True  False
# 1         1       1  female  38.0      1      0  65.6344       False  False
# 2         1       3  female  26.0      0      0   7.9250       False   True
#
#    Queenstown  Southampton
# 0       False         True
# 1       False        False
# 2       False         True

# %%
df['family'] = df['sibsp'] + df['parch']
df.drop(['sibsp' ,'parch'], axis=1, inplace=True)
df.head(3)
# Out:
#    survived  pclass     sex   age     fare  adult_male  alone  Queenstown  \
# 0         0       3    male  22.0   7.2500        True  False       False
# 1         1       1  female  38.0  65.6344       False  False       False
# 2         1       3  female  26.0   7.9250       False   True       False
#
#    Southampton  family
# 0         True       1
# 1        False       1
# 2         True       0

# %% [markdown]
# # division des données

# %%
from sklearn.model_selection import train_test_split
seed = 111
X = df.drop('survived', axis=1)
y = df['survived']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.4, 
                                         random_state = seed , stratify=y )
X_val, X_test, y_val, y_test = train_test_split(X_test,y_test, test_size = 0.5, 
                                         random_state = seed , stratify=y_test )

# %%
y.value_counts(normalize=True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64
